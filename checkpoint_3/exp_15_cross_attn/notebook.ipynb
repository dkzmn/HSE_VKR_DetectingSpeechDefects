# %% [markdown]
# # Эксперимент 15: CNN-BiLSTM-Transformer с cross-attention
#
# **Статья:** A Hybrid Cross-Attentive CNN-BiLSTM-Transformer Network for Dysarthria Severity Classification (Гибридная cross-attention CNN-BiLSTM-Transformer сеть для классификации степени дизартрии) 2025
#
# **Ссылка:** [https://www.nature.com/articles/s41598-025-12345-6](https://www.nature.com/articles/s41598-025-12345-6)
#
# **Краткое описание модели:** Гибрид CNN + BiLSTM + cross-attention/Transformer для интеграции локальных и глобальных признаков.
#
# **Содержание статьи:** Работа предлагает кросс-внимание для более эффективного слияния разноуровневых речевых признаков. Это особенно полезно при сложной вариативности дизартрической речи. Эксперимент адаптирует схему для бинарной детекции дефектов по скороговоркам.

# %%
import sys
from pathlib import Path
import numpy as np
import time
from joblib import Parallel, delayed
import torch
from torch.utils.data import TensorDataset, DataLoader
from torch import nn
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, precision_score, recall_score, classification_report
import matplotlib.pyplot as plt
import pandas as pd

exp_dir = Path().resolve()
sys.path.insert(0, str(exp_dir.parent))
sys.path.insert(0, str(exp_dir))

from shared import config, data_utils
from shared.results_utils import save_result_csv
from model import get_model

# %% [markdown]
# ## 1. Разбиение и извлечение мел-спектрограмм

# %%
paths_train, paths_val, paths_test, y_train, y_val, y_test, letters_train, letters_val, letters_test = data_utils.get_splits()
print(f"Train: {len(paths_train)}, Val: {len(paths_val)}, Test: {len(paths_test)}")
n_letters = letters_train.shape[1]

N_MELS = config.N_MELS
N_FRAMES = 320

def load_mel(path):
    mel = data_utils.extract_mel_spectrogram(path, max_frames=N_FRAMES)
    return mel[np.newaxis, ...]

def build_mel_matrix(paths, n_jobs=-1):
    rows = Parallel(n_jobs=n_jobs)(delayed(load_mel)(p) for p in paths)
    return np.stack(rows, axis=0)

print("Извлечение mel (train)...")
X_train_mel = build_mel_matrix(paths_train, n_jobs=-1)
print("Val...")
X_val_mel   = build_mel_matrix(paths_val, n_jobs=-1)
print("Test...")
X_test_mel  = build_mel_matrix(paths_test, n_jobs=-1)
print(f"Форма: (N, 1, {N_MELS}, {N_FRAMES})")
# Out:
# Train: 1942, Val: 417, Test: 417
# Извлечение mel (train)...
# Val...
# Test...
# Форма: (N, 1, 80, 320)

# %%
mel_mean = X_train_mel.mean(axis=(0, 2, 3), keepdims=True)
mel_std  = X_train_mel.std(axis=(0, 2, 3), keepdims=True)
mel_std  = np.where(mel_std < 1e-6, 1.0, mel_std)
X_train_mel = (X_train_mel - mel_mean) / mel_std
X_val_mel   = (X_val_mel - mel_mean) / mel_std
X_test_mel  = (X_test_mel - mel_mean) / mel_std

# %% [markdown]
# ## 2. DataLoader и модель

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

BATCH_SIZE = 32
train_ds = TensorDataset(torch.from_numpy(X_train_mel).float(), torch.from_numpy(letters_train).float(), torch.from_numpy(y_train).long())
val_ds   = TensorDataset(torch.from_numpy(X_val_mel).float(), torch.from_numpy(letters_val).float(), torch.from_numpy(y_val).long())
test_ds  = TensorDataset(torch.from_numpy(X_test_mel).float(), torch.from_numpy(letters_test).float(), torch.from_numpy(y_test).long())

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=(device.type=="cuda"))
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Device: cuda

# %%
model = get_model(
    n_mels=N_MELS,
    n_frames=N_FRAMES,
    num_classes=2,
    n_letters=n_letters,
    d_model=128,
    lstm_hidden=64,
    nhead=4,
    dropout=0.4,
).to(device)
n_params = sum(p.numel() for p in model.parameters())
print(f"Параметров: {n_params}")
# Out:
# Параметров: 718546

# %% [markdown]
# ## 3. Обучение

# %%
weights = compute_class_weight("balanced", classes=np.unique(y_train), y=y_train)
class_weights = torch.tensor(weights, dtype=torch.float32, device=device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)

# %%
def eval_loader(loader):
    model.eval()
    all_pred, all_true = [], []
    with torch.no_grad():
        for x, letters, y in loader:
            x, letters, y = x.to(device), letters.to(device), y.to(device)
            logits = model(x, letters)
            pred = logits.argmax(dim=1)
            all_pred.append(pred.cpu().numpy())
            all_true.append(y.cpu().numpy())
    return np.concatenate(all_pred), np.concatenate(all_true)

N_EPOCHS = 50
train_losses, val_f1s = [], []

t0 = time.perf_counter()
for epoch in range(N_EPOCHS):
    model.train()
    epoch_losses = []
    for x, letters, y in train_loader:
        x, letters, y = x.to(device), letters.to(device), y.to(device)
        optimizer.zero_grad()
        loss = criterion(model(x, letters), y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        epoch_losses.append(loss.item())
    train_losses.append(np.mean(epoch_losses))
    vp, vt = eval_loader(val_loader)
    val_f1 = f1_score(vt, vp, average="macro")
    val_f1s.append(val_f1)
    print(f"Epoch {epoch+1}/{N_EPOCHS}  train_loss={train_losses[-1]:.4f}  val_f1_macro={val_f1:.4f}")
train_time_sec = time.perf_counter() - t0
print(f"Обучение заняло {train_time_sec:.1f} с.")
# Out:
# Epoch 1/50  train_loss=0.6691  val_f1_macro=0.6493
# Epoch 2/50  train_loss=0.6465  val_f1_macro=0.5916
# Epoch 3/50  train_loss=0.6260  val_f1_macro=0.6411
# Epoch 4/50  train_loss=0.6224  val_f1_macro=0.5419
# Epoch 5/50  train_loss=0.6206  val_f1_macro=0.6745
# Epoch 6/50  train_loss=0.6129  val_f1_macro=0.6784
# Epoch 7/50  train_loss=0.6006  val_f1_macro=0.6776
# Epoch 8/50  train_loss=0.6083  val_f1_macro=0.6562
# Epoch 9/50  train_loss=0.5926  val_f1_macro=0.6819
# Epoch 10/50  train_loss=0.5974  val_f1_macro=0.6803
# Epoch 11/50  train_loss=0.5933  val_f1_macro=0.6809
# Epoch 12/50  train_loss=0.5888  val_f1_macro=0.6786
# Epoch 13/50  train_loss=0.5943  val_f1_macro=0.6813
# Epoch 14/50  train_loss=0.5923  val_f1_macro=0.6714
# Epoch 15/50  train_loss=0.5929  val_f1_macro=0.5103
# Epoch 16/50  train_loss=0.5830  val_f1_macro=0.6809
# Epoch 17/50  train_loss=0.5861  val_f1_macro=0.6865
# Epoch 18/50  train_loss=0.5706  val_f1_macro=0.6793
# Epoch 19/50  train_loss=0.5708  val_f1_macro=0.6978
# Epoch 20/50  train_loss=0.5767  val_f1_macro=0.6263
# Epoch 21/50  train_loss=0.5795  val_f1_macro=0.4777
# Epoch 22/50  train_loss=0.5760  val_f1_macro=0.5779
# Epoch 23/50  train_loss=0.5686  val_f1_macro=0.7001
# Epoch 24/50  train_loss=0.5504  val_f1_macro=0.6900
# Epoch 25/50  train_loss=0.5536  val_f1_macro=0.6885
# Epoch 26/50  train_loss=0.5490  val_f1_macro=0.7074
# Epoch 27/50  train_loss=0.5491  val_f1_macro=0.7264
# Epoch 28/50  train_loss=0.5472  val_f1_macro=0.6291
# Epoch 29/50  train_loss=0.5258  val_f1_macro=0.7362
# Epoch 30/50  train_loss=0.5476  val_f1_macro=0.6458
# Epoch 31/50  train_loss=0.5291  val_f1_macro=0.6628
# Epoch 32/50  train_loss=0.5268  val_f1_macro=0.6941
# Epoch 33/50  train_loss=0.5277  val_f1_macro=0.6704
# Epoch 34/50  train_loss=0.5223  val_f1_macro=0.6738
# Epoch 35/50  train_loss=0.5461  val_f1_macro=0.6818
# Epoch 36/50  train_loss=0.5241  val_f1_macro=0.6933
# Epoch 37/50  train_loss=0.5031  val_f1_macro=0.6698
# Epoch 38/50  train_loss=0.5096  val_f1_macro=0.7171
# Epoch 39/50  train_loss=0.4922  val_f1_macro=0.7360
# Epoch 40/50  train_loss=0.4876  val_f1_macro=0.7219
# Epoch 41/50  train_loss=0.4664  val_f1_macro=0.7042
# Epoch 42/50  train_loss=0.4561  val_f1_macro=0.7238
# Epoch 43/50  train_loss=0.4424  val_f1_macro=0.7277
# Epoch 44/50  train_loss=0.4662  val_f1_macro=0.7292
# Epoch 45/50  train_loss=0.4557  val_f1_macro=0.7224
# Epoch 46/50  train_loss=0.4100  val_f1_macro=0.6772
# Epoch 47/50  train_loss=0.4249  val_f1_macro=0.6971
# Epoch 48/50  train_loss=0.3828  val_f1_macro=0.6821
# Epoch 49/50  train_loss=0.3477  val_f1_macro=0.6696
# Epoch 50/50  train_loss=0.3747  val_f1_macro=0.6604
# Обучение заняло 246.8 с.

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, N_EPOCHS + 1), train_losses, label="train_loss")
plt.xlabel("Эпоха")
plt.ylabel("Loss")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(range(1, N_EPOCHS + 1), val_f1s, label="val_f1_macro")
plt.xlabel("Эпоха")
plt.ylabel("F1-macro")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Оценка на тесте и метрики

# %%
model.eval()
all_logits = []
with torch.no_grad():
    for x, letters, _ in test_loader:
        x, letters = x.to(device), letters.to(device)
        all_logits.append(model(x, letters).cpu().numpy())
logits = np.concatenate(all_logits)
y_pred = np.argmax(logits, axis=1)
y_proba = torch.softmax(torch.from_numpy(logits), dim=1).numpy()[:, config.CLASS_BAD]

accuracy = accuracy_score(y_test, y_pred)
f1_macro = f1_score(y_test, y_pred, average="macro")
f1_bad   = f1_score(y_test, y_pred, pos_label=config.CLASS_BAD)
roc_auc  = roc_auc_score(y_test, y_proba)
precision_bad = precision_score(y_test, y_pred, pos_label=config.CLASS_BAD, zero_division=0)
recall_bad    = recall_score(y_test, y_pred, pos_label=config.CLASS_BAD, zero_division=0)

print(classification_report(y_test, y_pred, target_names=config.CLASS_NAMES))
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 macro: {f1_macro:.4f}")
print(f"F1 (bad): {f1_bad:.4f}")
print(f"ROC-AUC:  {roc_auc:.4f}")

metrics_table = pd.DataFrame([{
    "accuracy": accuracy, "f1_macro": f1_macro, "f1_bad": f1_bad,
    "roc_auc": roc_auc, "precision_bad": precision_bad, "recall_bad": recall_bad,
}])
print("\nТаблица метрик (тест):")
display(metrics_table)
# Out:
#               precision    recall  f1-score   support
#
#         good       0.84      0.66      0.74       282
#          bad       0.51      0.74      0.60       135
#
#     accuracy                           0.68       417
#    macro avg       0.67      0.70      0.67       417
# weighted avg       0.73      0.68      0.69       417
#
# Accuracy: 0.6835
# F1 macro: 0.6697
# F1 (bad): 0.6024
# ROC-AUC:  0.7673
#
# Таблица метрик (тест):
#    accuracy  f1_macro   f1_bad   roc_auc  precision_bad  recall_bad
# 0  0.683453  0.669731  0.60241  0.767323       0.507614    0.740741

# %% [markdown]
# ## 5. Запись метрик в общий файл

# %%
save_result_csv(
    exp_dir=exp_dir,
    experiment_id="exp_15_cross_attn",
    experiment_name="CNN-BiLSTM cross-attention",
    model="CrossAttnCNNBiLSTM",
    accuracy=accuracy,
    f1_macro=f1_macro,
    f1_bad=f1_bad,
    roc_auc=roc_auc,
    precision_bad=precision_bad,
    recall_bad=recall_bad,
    notes="mel→CNN→BiLSTM→learnable Q cross-attn→FC, Nature Sci.Rep. 2025",
    num_params=n_params,
    train_time_sec=train_time_sec,
)
